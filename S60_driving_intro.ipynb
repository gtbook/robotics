# %% [markdown]
# <a href="https://colab.research.google.com/github/gtbook/robotics/blob/main/S60_driving_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install -q -U gtbook
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# no imports

# %% [markdown]
# # Autonomous Vehicles
#
# > Ackermann steering in $SE(2)$, LiDAR sensors, PoseSLAM, motion primitives, and Deep Reinforcement Learning.

# %%
from gtbook.display import randomImages
from IPython.display import display
display(randomImages(6, 0, "steampunk", 1))
# Out:
#         <div align='center'>
#         <img src='https://github.com/gtbook/robotics/blob/main/Art/steampunk/S60-Autonomous%20Vehicle%20with%20LIDAR%20and%20cameras-00.jpg?raw=1' style='height:256 width:100%'/>
#         </div>

# %% [markdown]
# In this chapter we look at some of the basic concepts involved in autonomous driving. Needless to say, the topic of autonomous vehicles is rather large, and we only cover a small selection in this chapter.
#
# We start out with becoming a bit more serious about movement in the plane, introducing SE(2) as a matrix Lie group. We then use that in Section 2 to introduce kinematics in the form of Ackermann steering. In terms of sensing, besides cameras, a very popular sensor in autonomous driving is the LIDAR sensor. We look at its basic geometry, and then cover iterative closest points (ICP) as a way to obtain relative pose measurements from successive LIDAR scans.
#
# In Section 4 we then also introduce simultaneous localization in mapping or SLAM, a very popular topic in robotics. Here we cover the most basic version, "Pose SLAM"", which only needs relative pose measurements.
#
# In section 5 we look at motion primitives to do some motion planning on the road. Finally, in section 6, we discussed the basics of deep reinforcement learning.
