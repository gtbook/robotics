# %%
# %pip install -q -U gtbook==0.0.13
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Introduction to Robotics and Perception
#
# > Frank Dellaert and Seth Hutchinson

# %%
from gtbook.display import randomImages
from IPython.display import display
display(randomImages(4, 0, "steampunk", 3))
display(randomImages(6, 0, "steampunk", 3))
# Out:
#         <div align='center'>
#         <img src='https://github.com/gtbook/robotics/blob/main/Art/steampunk/S40-Warehouse%20robots-07.jpg?raw=1' style='height:256 width:33%'/> <img src='https://github.com/gtbook/robotics/blob/main/Art/steampunk/S40-Warehouse%20robots-04.jpg?raw=1' style='height:256 width:33%'/> <img src='https://github.com/gtbook/robotics/blob/main/Art/steampunk/S40-Warehouse%20robots-05.jpg?raw=1' style='height:256 width:33%'/>
#         </div>
#         <div align='center'>
# ...

# %% [markdown]
# About the art: all images were generated by Frank Dellaert using [OpenAI's Glide code](https://github.com/openai/glide-text2im), based on the chapter and section topics. Images are selected at random each time the book is re-generated.
